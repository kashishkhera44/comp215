# %% [markdown]
# <a href="https://colab.research.google.com/github/kashishkhera44/comp215/blob/main/labs/lab01-introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COMP 215 - LAB 1
# ----------------
# #### Name(s):
# #### Date:
#
#
# By the end of this lab you should be able to:
# - write Python code using Google Colaboratory (Colab)
# - save the code in GitHub
# - submit the code on eLearn
#
#
# During this lab, you will be introduced to the following:
# - Application Programming Interfaces (API's)
# - JSON data formats
# - list comprehension in Python
# - plotting with matplotlib

# %% [markdown]
# ## GitHub Introduction
#
# GitHub is a code “repository” where many professional programmers keep their software projects, especially for open-source projects. It runs the “git” version control system to track all changes made to a project over time. Colab and GitHub play (relatively) nicely together, so this is a perfect opportunity to start using GitHub, and start building your own portfolio of code projects.  To start, watch this [What is GitHub?](https://www.youtube.com/watch?v=pBy1zgt0XPc) video.
#
#
#
# 1.   If you don't already have one, get a GitHub account by going to [github.com](github.com) to create an account.  Remember this account might be a long-term prospect, so choose your username thinking about the future.
#
# 2.   Complete the [GitHub 'Hello World' tutorial](https://docs.github.com/en/get-started/start-your-journey/hello-world).  This will introduce you to the basic ideas of GitHub.  For this course, you will *fork* (ie. make a copy of) the *main branch* (ie. current version) of the `comp215` *repository* (ie. files and folders of code).  You will complete all your work in your *fork*.  You will **not** need to do a *pull request* to *merge* your changes because you will be submitting work in your *fork*.  After completing the GitHub 'Hello World' tutorial, you should understand the italicized words.
#
# 3. In your GitHub account, fork the `comp215` repo: [https://github.com/Hamilton-at-CapU/comp215/](https://github.com/Hamilton-at-CapU/comp215).  This is now your personal copy you can edit and make changes to.  You will be using this fork to submit your code in this course.
#
# Note that GitHub stores your code, it does not run your code.  We will be using Google Colaboratory to run the code.

# %% [markdown]
# ## Google Colaboratory Introduction
#
# You will need a Google gmail account to access and use Colab.  You can use your personal gmail account, or you can create a gmail account just for this class.
#
# Accroding to the Google AI Overview;
#   *  *Google Colaboratory (Colab), is a free, cloud-based environment for writing and running Python code in a browser. It's a popular tool in the data science and machine learning communities for tasks that require a lot of computing power, such as: Analyzing large amounts of data, Training machine learning models, and Testing deep learning algorithms.*
#
# Colab is an online interactive Python notebook environment.  An interactive notebook is a programming environment that allows you to interlace code, formatted text, data, and graphical output all in a single document. These notebooks are easy to distribute on the web and can be viewed and executed without any additional software installation or configuration, making them an ideal platform for sharing research and analysis. They are widely used in scientific computing and in data science applications where the emphasis is on using code to clearly communicate rather than building an end-user app.  Interactive Python notebooks use the file extension `.ipynb` instead of `.py`.
#
# You can find more information about Jupyter Notebooks at [jupyter.org](https://jupyter.org/).  Note that you do not need to install Jupyter on your computer because we are using Colab.  In a notebook you write the code in Python and the text in a language called Markdown.  You can find more information about the Markdown language at [markdownguide.org](https://www.markdownguide.org).  We will be using Colab in this course as the default (but not required) Integrated Development Environment (IDE) for you to write and run Python code.
#
#  1. Go to [colab.research.google.com](colab.research.google.com)
#  2. Log in with your Google (ie. gmail) account.  If you do not already have one, or do not want to use your personal Google account for this course, then please create a Google account specifically for this course.
#  3. Create a "New Notebook" to write and run a 'hello world' program just to be sure your account works.  You can delete the new notebook after checking that Colab is working for you.

# %% [markdown]
# ## Colab & GitHub
#
# You can now open the Notebooks from your GitHub repository in Colab.
#
# 1. In your `comp215` fork, go to `labs` folder and open `lab01_introduction.ipynb`.  Open the file in Google Colaboratory using the [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Hamilton-at-CapU/comp215/blob/main/labs/lab01_introduction.ipynb) button at the top of the file.  Alternatively, for any Python Notebook (`.ipynb` file) in GitHub you can replace in the address bar:
# ```
# github.com → colab.research.google.com/github
# ```
# to open the Notebook in Colab.  For example:
#  - in GitHub, this Notebook is ```github.com/Hamilton-at-CapU/comp215/blob/main/labs/lab01-introduction.ipynb```
#  - in Colab, this Notebook is ```colab.research.google.com/github/Hamilton-at-CapU/comp215/blob/main/labs/lab01-introduction.ipynb```
#
# 2. Alternatively, you can go to [colab.research.google.com](colab.research.google.com) and open the GitHub files directly in the "Open Notebook" pop-up window that appears.
#
# Continue with the rest of this lab in Colab.

# %% [markdown]
# ## Committing (saving) changes to GitHub and submitting your lab on eLearn
#
# Below is a code block.  Write a 'hello world' print statement in the code block and run it.

# %%
# This is a code block.

# %% [markdown]
# #### Text Blocks
#
# Below is a text block.  Write 'hello world' in the text block in bold-italic font.

# %% [markdown]
# This is a text block.

# %% [markdown]
#  - Now that you have edited the Colab file, it's time to `commit` (ie. save) the changes to your GitHub repository.  Click the `Save in GitHub to keep changes` in the Colab menu bar to save your changes to your GitHub repository.
#  - A window will pop up, allowing you to select which repository, branch, and file path to commit it to (the defaults should be correct), as well as enter a `Commit message`.  This `Commit message` appears in GitHub beside the filename; it is meant to be a short reminder of what you last changed in the file.  So, something like 'first commit' would make sense for this one.  There is also an `Include a link to Colab` tick box, please select it so that I can easily open your code from GitHub.
#  - Go to GitHub and check that your changes were committed to your repository.
#  - Submit your lab by copying the URL of your lab file in GitHub to the submission link in eLearn.  The URL should be something like:
#
#  ```https://github.com/YourAwesomeUsername/comp215/blob/main/labs/lab01_introduction.ipynb```
#
#  (note that it is a link to github.com, not colab.research.google.com)
#  - You can now continue to edit your code in Colab, commit the changes to GitHub, and the link you submitted on eLearn will include the new commits.  I will be able to see the date/time and changes of each of your GitHub commits, so please don't commit any changes after the due date of the lab.

# %% [markdown]
# ## Finally, now for Some Coding!
#
# Now that you understand how to submit your code, let's actaully write some code.  For this first lab we will be plotting some earthquake data from the [U.S. Geological Survey (USGS)](https://www.usgs.gov/programs/earthquake-hazards) [API](https://earthquake.usgs.gov/fdsnws/event/1/).
#
#
# ### What is an API?
#
# An API (Application Programming interface) is a way for two different applications to communicate. Whilst the term applies to any two programs we are using it to refer to the API of a web service that provides data.  To retrieve data from an API, a request to a remote web server is made.  For example, if you want to build an application which plots stock prices, you would use the API of something like google finance to request the current stock prices (ref [API tutorial](https://colab.research.google.com/github/nestauk/im-tutorials/blob/3-ysi-tutorial/notebooks/APIs/API_tutorial.ipynb)).
#
# The code below retrieves earthquake information for all 'green' level earthquakes that occured in 2024 using the ['geojson' format](https://earthquake.usgs.gov/earthquakes/feed/v1.0/geojson.php).  Note that similar information can be retrieved using a [USGS ComCat library](https://code.usgs.gov/ghsc/esi/libcomcat-python/-/blob/main/docs/api.md), but we will not use that method for this lab.

# %%
# imports for API request
import requests
import json
from pprint import pprint

# %%
# define the API parameters
params_dict = {'format': 'geojson', 'starttime': '2024-01-01', 'endtime': '2024-12-31', 'alertlevel': 'green'}
api_url = 'https://earthquake.usgs.gov/fdsnws/event/1/query?'

# make the API request
response = requests.get(api_url, params = params_dict)

# convert the response to json format data
data = json.loads(response.text)
pprint(data)
# print out some of the data 'features'
#for event in (data['features']):
 # print(event['properties']['time'], event['geometry']['coordinates'], event['properties']['place'], event['properties']['mag'])
# Out:
# Streaming output truncated to the last 5000 lines.
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000m8yd&format=geojson',
#                               'dmin': 0.163,
#                               'felt': None,
#                               'gap': 25,
#                               'ids': ',at00sb65s9,usauto7000m8yd,pt24090000,us7000m8yd,ak0244542aha,',
#                               'mag': 5.8,
#                               'magType': 'mww',
#                               'mmi': 3.786,
#                               'net': 'us',
#                               'nst': 326,
#                               'place': 'Rat Islands, Aleutian Islands, Alaska',
#                               'rms': 0.87,
#                               'sig': 518,
#                               'sources': ',at,usauto,pt,us,ak,',
#                               'status': 'reviewed',
#                               'time': 1711816137456,
#                               'title': 'M 5.8 - Rat Islands, Aleutian Islands, '
#                                        'Alaska',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',impact-link,internal-moment-tensor,internal-origin,losspager,moment-tensor,oaf,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1736008745408,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m8yd'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-178.0987, -27.9628, 10],
#                             'type': 'Point'},
#                'id': 'us7000m8rg',
#                'properties': {'alert': 'green',
#                               'cdi': None,
#                               'code': '7000m8rg',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000m8rg&format=geojson',
#                               'dmin': 1.286,
#                               'felt': None,
#                               'gap': 78,
#                               'ids': ',usauto7000m8rg,us7000m8rg,',
#                               'mag': 5.4,
#                               'magType': 'mww',
#                               'mmi': 2.717,
#                               'net': 'us',
#                               'nst': 85,
#                               'place': 'Kermadec Islands region',
#                               'rms': 1.04,
#                               'sig': 449,
#                               'sources': ',usauto,us,',
#                               'status': 'reviewed',
#                               'time': 1711723256146,
#                               'title': 'M 5.4 - Kermadec Islands region',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',internal-moment-tensor,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1717278949040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m8rg'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [149.5876, -4.562, 570.902],
#                             'type': 'Point'},
#                'id': 'us7000m8qr',
#                'properties': {'alert': 'green',
#                               'cdi': None,
#                               'code': '7000m8qr',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000m8qr&format=geojson',
#                               'dmin': 3.343,
#                               'felt': None,
#                               'gap': 34,
#                               'ids': ',usauto7000m8qr,us7000m8qr,',
#                               'mag': 5.6,
#                               'magType': 'mww',
#                               'mmi': 3.568,
#                               'net': 'us',
#                               'nst': 127,
#                               'place': '125 km NNW of Kimbe, Papua New Guinea',
#                               'rms': 0.54,
#                               'sig': 482,
#                               'sources': ',usauto,us,',
#                               'status': 'reviewed',
#                               'time': 1711706225507,
#                               'title': 'M 5.6 - 125 km NNW of Kimbe, Papua New '
#                                        'Guinea',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',internal-moment-tensor,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1717278949040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m8qr'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [21.2557, 37.3224, 26.873],
#                             'type': 'Point'},
#                'id': 'us7000m8q9',
#                'properties': {'alert': 'green',
#                               'cdi': 7,
#                               'code': '7000m8q9',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000m8q9&format=geojson',
#                               'dmin': 0.553,
#                               'felt': 30,
#                               'gap': 32,
#                               'ids': ',us7000m8q9,usauto7000m8q9,pt24089000,',
#                               'mag': 5.8,
#                               'magType': 'mww',
#                               'mmi': 5.276,
#                               'net': 'us',
#                               'nst': 209,
#                               'place': '34 km WNW of Filiatrá, Greece',
#                               'rms': 1.16,
#                               'sig': 539,
#                               'sources': ',us,usauto,pt,',
#                               'status': 'reviewed',
#                               'time': 1711696368063,
#                               'title': 'M 5.8 - 34 km WNW of Filiatrá, Greece',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',dyfi,impact-text,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1717278949040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m8q9'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [173.8203, -20.754, 10],
#                             'type': 'Point'},
#                'id': 'us7000m8an',
#                'properties': {'alert': 'green',
#                               'cdi': None,
#                               'code': '7000m8an',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000m8an&format=geojson',
#                               'dmin': 4.994,
#                               'felt': None,
#                               'gap': 39,
#                               'ids': ',usauto7000m8an,us7000m8an,',
#                               'mag': 5.3,
#                               'magType': 'mww',
#                               'mmi': 2.788,
#                               'net': 'us',
#                               'nst': 100,
#                               'place': 'Vanuatu region',
#                               'rms': 0.49,
#                               'sig': 432,
#                               'sources': ',usauto,us,',
#                               'status': 'reviewed',
#                               'time': 1711547357821,
#                               'title': 'M 5.3 - Vanuatu region',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',internal-moment-tensor,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1717278947040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m8an'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-126.7243, 42.3102, 10],
#                             'type': 'Point'},
#                'id': 'us7000m875',
#                'properties': {'alert': 'green',
#                               'cdi': 3.4,
#                               'code': '7000m875',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000m875&format=geojson',
#                               'dmin': 1.762,
#                               'felt': 27,
#                               'gap': 116,
#                               'ids': ',us7000m875,at00sazlek,usauto7000m875,',
#                               'mag': 5.6,
#                               'magType': 'mww',
#                               'mmi': 3.095,
#                               'net': 'us',
#                               'nst': 130,
#                               'place': '189 km WSW of Port Orford, Oregon',
#                               'rms': 0.55,
#                               'sig': 492,
#                               'sources': ',us,at,usauto,',
#                               'status': 'reviewed',
#                               'time': 1711509782962,
#                               'title': 'M 5.6 - 189 km WSW of Port Orford, '
#                                        'Oregon',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',dyfi,ground-failure,impact-link,internal-moment-tensor,losspager,moment-tensor,oaf,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1736307189518,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m875'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [173.7373, -21.0715, 10],
#                             'type': 'Point'},
#                'id': 'us7000m86i',
#                'properties': {'alert': 'green',
#                               'cdi': None,
#                               'code': '7000m86i',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000m86i&format=geojson',
#                               'dmin': 5.247,
#                               'felt': None,
#                               'gap': 43,
#                               'ids': ',at00sazg39,us7000m86i,pt24087000,usauto7000m86i,at00sazg3d,',
#                               'mag': 6.4,
#                               'magType': 'mww',
#                               'mmi': 3.905,
#                               'net': 'us',
#                               'nst': 81,
#                               'place': 'Vanuatu region',
#                               'rms': 0.79,
#                               'sig': 630,
#                               'sources': ',at,us,pt,usauto,at,',
#                               'status': 'reviewed',
#                               'time': 1711502897689,
#                               'title': 'M 6.4 - Vanuatu region',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',associate,ground-failure,impact-link,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1717278947040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m86i'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-15.3842, -1.5815, 10],
#                             'type': 'Point'},
#                'id': 'us7000m82w',
#                'properties': {'alert': 'green',
#                               'cdi': None,
#                               'code': '7000m82w',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000m82w&format=geojson',
#                               'dmin': 6.269,
#                               'felt': None,
#                               'gap': 28,
#                               'ids': ',usauto7000m82w,us7000m82w,',
#                               'mag': 5.4,
#                               'magType': 'mww',
#                               'mmi': 0,
#                               'net': 'us',
#                               'nst': 267,
#                               'place': 'north of Ascension Island',
#                               'rms': 0.47,
#                               'sig': 449,
#                               'sources': ',usauto,us,',
#                               'status': 'reviewed',
#                               'time': 1711458848949,
#                               'title': 'M 5.4 - north of Ascension Island',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',internal-moment-tensor,losspager,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1717278947040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m82w'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-174.1986, -20.6273, 14.482],
#                             'type': 'Point'},
#                'id': 'us7000m826',
#                'properties': {'alert': 'green',
#                               'cdi': None,
#                               'code': '7000m826',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000m826&format=geojson',
#                               'dmin': 1.084,
#                               'felt': None,
#                               'gap': 135,
#                               'ids': ',usauto7000m826,us7000m826,',
#                               'mag': 5.3,
#                               'magType': 'mww',
#                               'mmi': 3.332,
#                               'net': 'us',
#                               'nst': 63,
#                               'place': '91 km S of Pangai, Tonga',
#                               'rms': 0.93,
#                               'sig': 432,
#                               'sources': ',usauto,us,',
#                               'status': 'reviewed',
#                               'time': 1711445835185,
#                               'title': 'M 5.3 - 91 km S of Pangai, Tonga',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',internal-moment-tensor,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1717278947040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m826'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [158.6349, -59.0543, 10],
#                             'type': 'Point'},
#                'id': 'us7000m7xz',
#                'properties': {'alert': 'green',
#                               'cdi': None,
#                               'code': '7000m7xz',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000m7xz&format=geojson',
#                               'dmin': 4.571,
#                               'felt': None,
#                               'gap': 114,
#                               'ids': ',usauto7000m7xz,us7000m7xz,',
#                               'mag': 5.5,
#                               'magType': 'mww',
#                               'mmi': 0,
#                               'net': 'us',
#                               'nst': 33,
#                               'place': 'Macquarie Island region',
#                               'rms': 0.75,
#                               'sig': 465,
#                               'sources': ',usauto,us,',
#                               'status': 'reviewed',
#                               'time': 1711386002616,
#                               'title': 'M 5.5 - Macquarie Island region',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',internal-moment-tensor,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1717278946040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000m7xz'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-46.462, 16.5556, 10],
#                             'type': 'Point'},
#                'id': 'us6000ml19',
#                'properties': {'alert': 'green',
#                               'cdi': None,
#                               'code': '6000ml19',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000ml19&format=geojson',
#                               'dmin': 12.889,
#                               'felt': None,
#                               'gap': 54,
#                               'ids': ',usauto6000ml19,us6000ml19,',
#                               'mag': 5.5,
#                               'magType': 'mww',
#                               'mmi': 0,
#                               'net': 'us',
#                               'nst': 301,
#                               'place': 'northern Mid-Atlantic Ridge',
#                               'rms': 0.56,
#                               'sig': 465,
#                               'sources': ',usauto,us,',
#                               'status': 'reviewed',
#                               'time': 1711344137065,
#                               'title': 'M 5.5 - northern Mid-Atlantic Ridge',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',internal-moment-tensor,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1717278946040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000ml19'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [122.1832, -9.4207, 62.174],
#                             'type': 'Point'},
#                'id': 'us6000mkvx',
#                'properties': {'alert': 'green',
#                               'cdi': None,
#                               'code': '6000mkvx',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000mkvx&format=geojson',
#                               'dmin': 2.082,
#                               'felt': None,
#                               'gap': 52,
#                               'ids': ',usauto6000mkvx,pt24084000,us6000mkvx,',
#                               'mag': 5.7,
#                               'magType': 'mww',
#                               'mmi': 3.932,
#                               'net': 'us',
#                               'nst': 126,
#                               'place': '85 km SE of Ende, Indonesia',
#                               'rms': 0.98,
#                               'sig': 500,
#                               'sources': ',usauto,pt,us,',
#                               'status': 'reviewed',
#                               'time': 1711249447847,
#                               'title': 'M 5.7 - 85 km SE of Ende, Indonesia',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1716819563040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mkvx'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [143.134, -4.1292, 41.464],
#                             'type': 'Point'},
#                'id': 'us6000mksx',
#                'properties': {'alert': 'green',
#                               'cdi': 8.2,
#                               'code': '6000mksx',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000mksx&format=geojson',
#                               'dmin': 2.909,
#                               'felt': 29,
#                               'gap': 32,
#                               'ids': ',at00sathwu,us6000mksx,pt24083000,at00sathwv,usauto6000mksx,',
#                               'mag': 6.9,
#                               'magType': 'mww',
#                               'mmi': 7.234,
#                               'net': 'us',
#                               'nst': 147,
#                               'place': '36 km ENE of Ambunti, Papua New Guinea',
#                               'rms': 0.76,
#                               'sig': 756,
#                               'sources': ',at,us,pt,at,usauto,',
#                               'status': 'reviewed',
#                               'time': 1711225324348,
#                               'title': 'M 6.9 - 36 km ENE of Ambunti, Papua '
#                                        'New Guinea',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',associate,dyfi,ground-failure,impact-link,impact-text,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1728464821269,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mksx'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [112.3187, -5.8155, 10],
#                             'type': 'Point'},
#                'id': 'us6000mkej',
#                'properties': {'alert': 'green',
#                               'cdi': 7.3,
#                               'code': '6000mkej',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000mkej&format=geojson',
#                               'dmin': 2.233,
#                               'felt': 61,
#                               'gap': 27,
#                               'ids': ',us6000mkej,usauto6000mkej,',
#                               'mag': 5.6,
#                               'magType': 'mww',
#                               'mmi': 6.631,
#                               'net': 'us',
#                               'nst': 89,
#                               'place': '117 km N of Paciran, Indonesia',
#                               'rms': 1.12,
#                               'sig': 527,
#                               'sources': ',us,usauto,',
#                               'status': 'reviewed',
#                               'time': 1711081365531,
#                               'title': 'M 5.6 - 117 km N of Paciran, Indonesia',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',dyfi,impact-text,internal-moment-tensor,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1716819561040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mkej'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-27.259, -56.2515, 89],
#                             'type': 'Point'},
#                'id': 'us6000mjx0',
#                'properties': {'alert': 'green',
#                               'cdi': None,
#                               'code': '6000mjx0',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000mjx0&format=geojson',
#                               'dmin': 5.633,
#                               'felt': None,
#                               'gap': 32,
#                               'ids': ',usauto6000mjx0,pt24080000,us6000mjx0,',
#                               'mag': 5.6,
#                               'magType': 'mww',
#                               'mmi': 4.064,
#                               'net': 'us',
#                               'nst': 108,
#                               'place': 'South Sandwich Islands region',
#                               'rms': 1.04,
#                               'sig': 482,
#                               'sources': ',usauto,pt,us,',
#                               'status': 'reviewed',
#                               'time': 1710913698048,
#                               'title': 'M 5.6 - South Sandwich Islands region',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1716819559040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mjx0'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [65.3531, 29.7493, 6],
#                             'type': 'Point'},
#                'id': 'us6000mjux',
#                'properties': {'alert': 'green',
#                               'cdi': 4,
#                               'code': '6000mjux',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000mjux&format=geojson',
#                               'dmin': 7.784,
#                               'felt': 14,
#                               'gap': 73,
#                               'ids': ',us6000mjux,usauto6000mjux,',
#                               'mag': 5.3,
#                               'magType': 'mww',
#                               'mmi': 6.784,
#                               'net': 'us',
#                               'nst': 162,
#                               'place': '68 km WNW of Nushki, Pakistan',
#                               'rms': 1.02,
#                               'sig': 438,
#                               'sources': ',us,usauto,',
#                               'status': 'reviewed',
#                               'time': 1710883621034,
#                               'title': 'M 5.3 - 68 km WNW of Nushki, Pakistan',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',dyfi,internal-moment-tensor,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1716819559040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mjux'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-143.3884, -56.4959, 10],
#                             'type': 'Point'},
#                'id': 'us6000mk0i',
#                'properties': {'alert': 'green',
#                               'cdi': None,
#                               'code': '6000mk0i',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000mk0i&format=geojson',
#                               'dmin': 32.845,
#                               'felt': None,
#                               'gap': 64,
#                               'ids': ',us6000mk0i,',
#                               'mag': 5.5,
#                               'magType': 'mww',
#                               'mmi': 0,
#                               'net': 'us',
#                               'nst': 24,
#                               'place': 'Pacific-Antarctic Ridge',
#                               'rms': 0.76,
#                               'sig': 465,
#                               'sources': ',us,',
#                               'status': 'reviewed',
#                               'time': 1710871622532,
#                               'title': 'M 5.5 - Pacific-Antarctic Ridge',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1716819560040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mk0i'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-179.131, -31.2982, 9.961],
#                             'type': 'Point'},
#                'id': 'us6000mjpw',
#                'properties': {'alert': 'green',
#                               'cdi': None,
#                               'code': '6000mjpw',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000mjpw&format=geojson',
#                               'dmin': 2.284,
#                               'felt': None,
#                               'gap': 48,
#                               'ids': ',usauto6000mjpw,us6000mjpw,',
#                               'mag': 5.5,
#                               'magType': 'mww',
#                               'mmi': 7.05,
#                               'net': 'us',
#                               'nst': 53,
#                               'place': 'Kermadec Islands region',
#                               'rms': 0.56,
#                               'sig': 465,
#                               'sources': ',usauto,us,',
#                               'status': 'reviewed',
#                               'time': 1710815131684,
#                               'title': 'M 5.5 - Kermadec Islands region',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',internal-moment-tensor,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1716819559040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mjpw'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-125.2541667, 40.3823333, 10],
#                             'type': 'Point'},
#                'id': 'nc74019716',
#                'properties': {'alert': 'green',
#                               'cdi': 3.8,
#                               'code': '74019716',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc74019716&format=geojson',
#                               'dmin': 0.7031,
#                               'felt': 5,
#                               'gap': 264,
#                               'ids': ',nc74019716,us6000mjpv,',
#                               'mag': 3.44,
#                               'magType': 'ml',
#                               'mmi': 1.58,
#                               'net': 'nc',
#                               'nst': 50,
#                               'place': '82 km W of Petrolia, CA',
#                               'rms': 0.29,
#                               'sig': 184,
#                               'sources': ',nc,us,',
#                               'status': 'reviewed',
#                               'time': 1710815006780,
#                               'title': 'M 3.4 - 82 km W of Petrolia, CA',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',dyfi,losspager,nearby-cities,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1716819559040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc74019716'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [65.3791, 29.6902, 8],
#                             'type': 'Point'},
#                'id': 'us6000mjpj',
#                'properties': {'alert': 'green',
#                               'cdi': 5.3,
#                               'code': '6000mjpj',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000mjpj&format=geojson',
#                               'dmin': 5.769,
#                               'felt': 12,
#                               'gap': 22,
#                               'ids': ',us6000mjpj,usauto6000mjpj,pt24079000,',
#                               'mag': 5.5,
#                               'magType': 'mww',
#                               'mmi': 6.902,
#                               'net': 'us',
#                               'nst': 279,
#                               'place': '64 km WNW of Nushki, Pakistan',
#                               'rms': 0.55,
#                               'sig': 472,
#                               'sources': ',us,usauto,pt,',
#                               'status': 'reviewed',
#                               'time': 1710808518851,
#                               'title': 'M 5.5 - 64 km WNW of Nushki, Pakistan',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',dyfi,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1716819559040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mjpj'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [142.7619, 24.2346, 35],
#                             'type': 'Point'},
#                'id': 'us6000mjkb',
#                'properties': {'alert': 'green',
#                               'cdi': None,
#                               'code': '6000mjkb',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000mjkb&format=geojson',
#                               'dmin': 2.896,
#                               'felt': None,
#                               'gap': 25,
#                               'ids': ',usauto6000mjkb,us6000mjkb,',
#                               'mag': 5.3,
#                               'magType': 'mww',
#                               'mmi': 2.917,
#                               'net': 'us',
#                               'nst': 119,
#                               'place': 'Volcano Islands, Japan region',
#                               'rms': 1.09,
#                               'sig': 432,
#                               'sources': ',usauto,us,',
#                               'status': 'reviewed',
#                               'time': 1710759881113,
#                               'title': 'M 5.3 - Volcano Islands, Japan region',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',internal-moment-tensor,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1716819558040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mjkb'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [148.6471, -3.3388, 10],
#                             'type': 'Point'},
#                'id': 'us6000mjfc',
#                'properties': {'alert': 'green',
#                               'cdi': None,
#                               'code': '6000mjfc',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000mjfc&format=geojson',
#                               'dmin': 3.49,
#                               'felt': None,
#                               'gap': 54,
#                               'ids': ',usauto6000mjfc,us6000mjfc,',
#                               'mag': 5.3,
#                               'magType': 'mww',
#                               'mmi': 3.116,
#                               'net': 'us',
#                               'nst': 79,
#                               'place': '210 km SE of Lorengau, Papua New '
#                                        'Guinea',
#                               'rms': 0.62,
#                               'sig': 432,
#                               'sources': ',usauto,us,',
#                               'status': 'reviewed',
#                               'time': 1710673816687,
#                               'title': 'M 5.3 - 210 km SE of Lorengau, Papua '
#                                        'New Guinea',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',internal-moment-tensor,losspager,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1716067415040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mjfc'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-87.6546, 12.3856, 48],
#                             'type': 'Point'},
#                'id': 'us6000mjct',
#                'properties': {'alert': 'green',
#                               'cdi': 3.8,
#                               'code': '6000mjct',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000mjct&format=geojson',
#                               'dmin': 0.692,
#                               'felt': 11,
#                               'gap': 91,
#                               'ids': ',us6000mjct,usauto6000mjct,',
#                               'mag': 5.6,
#                               'magType': 'mww',
#                               'mmi': 4.087,
#                               'net': 'us',
#                               'nst': 180,
#                               'place': '45 km SSW of Jiquilillo, Nicaragua',
#                               'rms': 1.08,
#                               'sig': 487,
#                               'sources': ',us,usauto,',
#                               'status': 'reviewed',
#                               'time': 1710636242920,
#                               'title': 'M 5.6 - 45 km SSW of Jiquilillo, '
#                                        'Nicaragua',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',dyfi,internal-moment-tensor,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1716067407040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mjct'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [158.3538, -58.935, 10],
#                             'type': 'Point'},
#                'id': 'us6000mj77',
#                'properties': {'alert': 'green',
#                               'cdi': None,
#                               'code': '6000mj77',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000mj77&format=geojson',
#                               'dmin': 4.46,
#                               'felt': None,
#                               'gap': 52,
#                               'ids': ',usauto6000mj77,at00saezcu,us6000mj77,',
#                               'mag': 5.9,
#                               'magType': 'mww',
#                               'mmi': 0,
#                               'net': 'us',
#                               'nst': 57,
#                               'place': 'Macquarie Island region',
#                               'rms': 0.5,
#                               'sig': 536,
#                               'sources': ',usauto,at,us,',
#                               'status': 'reviewed',
#                               'time': 1710548091989,
#                               'title': 'M 5.9 - Macquarie Island region',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1716067395040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mj77'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [130.1034, 28.4192, 20],
#                             'type': 'Point'},
#                'id': 'us6000mj1l',
#                'properties': {'alert': 'green',
#                               'cdi': 4.7,
#                               'code': '6000mj1l',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000mj1l&format=geojson',
#                               'dmin': 2.264,
#                               'felt': 2,
#                               'gap': 78,
#                               'ids': ',us6000mj1l,usauto6000mj1l,',
#                               'mag': 5.6,
#                               'magType': 'mww',
#                               'mmi': 5.54,
#                               'net': 'us',
#                               'nst': 238,
#                               'place': '49 km E of Tatsugō, Japan',
#                               'rms': 0.51,
#                               'sig': 483,
#                               'sources': ',us,usauto,',
#                               'status': 'reviewed',
#                               'time': 1710498770046,
#                               'title': 'M 5.6 - 49 km E of Tatsugō, Japan',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',dyfi,internal-moment-tensor,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1716067384040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000mj1l'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-42.6288, 29.6206, 10],
#                             'type': 'Point'},
#                'id': 'us6000miya',
#                'properties': {'alert': 'green',
#                               'cdi': None,
#                               'code': '6000miya',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000miya&format=geojson',
#                               'dmin': 16.372,
#                               'felt': None,
#                               'gap': 68,
#                               'ids': ',usauto6000miya,us6000miya,',
#                               'mag': 5.4,
#                               'magType': 'mww',
#                               'mmi': 0,
#                               'net': 'us',
#                               'nst': 102,
#                               'place': 'northern Mid-Atlantic Ridge',
#                               'rms': 0.52,
#                               'sig': 449,
#                               'sources': ',usauto,us,',
#                               'status': 'reviewed',
#                               'time': 1710451752936,
#                               'title': 'M 5.4 - northern Mid-Atlantic Ridge',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',internal-moment-tensor,losspager,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1716067378040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000miya'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-42.6608, 29.7971, 10],
#                             'type': 'Point'},
#                'id': 'us6000miy6',
#                'properties': {'alert': 'green',
#                               'cdi': None,
#                               'code': '6000miy6',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000miy6&format=geojson',
#                               'dmin': 16.297,
#                               'felt': None,
#                               'gap': 54,
#                               'ids': ',usauto6000miy6,at00sacw5g,pt24074001,us6000miy6,',
#                               'mag': 6.2,
#                               'magType': 'mww',
#                               'mmi': 0,
#                               'net': 'us',
#                               'nst': 189,
#                               'place': 'northern Mid-Atlantic Ridge',
#                               'rms': 0.59,
#                               'sig': 591,
#                               'sources': ',usauto,at,pt,us,',
#                               'status': 'reviewed',
#                               'time': 1710450624786,
#                               'title': 'M 6.2 - northern Mid-Atlantic Ridge',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1716067378040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000miy6'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [141.1231, 37.083, 44],
#                             'type': 'Point'},
#                'id': 'us6000miuf',
#                'properties': {'alert': 'green',
#                               'cdi': 6.1,
#                               'code': '6000miuf',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000miuf&format=geojson',
#                               'dmin': 2.4,
#                               'felt': 35,
#                               'gap': 71,
#                               'ids': ',us6000miuf,usauto6000miuf,',
#                               'mag': 5.6,
#                               'magType': 'mww',
#                               'mmi': 4.052,
#                               'net': 'us',
#                               'nst': 122,
#                               'place': '21 km E of Iwaki, Japan',
#                               'rms': 0.78,
#                               'sig': 504,
#                               'sources': ',us,usauto,',
#                               'status': 'reviewed',
#                               'time': 1710429275701,
#                               'title': 'M 5.6 - 21 km E of Iwaki, Japan',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',dyfi,internal-moment-tensor,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1716067374040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000miuf'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-150.508, 62.8544, 101.6],
#                             'type': 'Point'},
#                'id': 'ak0243eh222y',
#                'properties': {'alert': 'green',
#                               'cdi': 3.4,
#                               'code': '0243eh222y',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0243eh222y&format=geojson',
#                               'dmin': None,
#                               'felt': 27,
#                               'gap': None,
# ...
#                               'time': 1704344197532,
#                               'title': 'M 5.7 - 125 km W of Houma, Tonga',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1710020353040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000m1ld'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-68.8167, -28.4508, 117],
#                             'type': 'Point'},
#                'id': 'us6000m1cg',
#                'properties': {'alert': 'green',
#                               'cdi': None,
#                               'code': '6000m1cg',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000m1cg&format=geojson',
#                               'dmin': 1.743,
#                               'felt': None,
#                               'gap': 29,
#                               'ids': ',usauto6000m1cg,us6000m1cg,',
#                               'mag': 5.5,
#                               'magType': 'mww',
#                               'mmi': 3.806,
#                               'net': 'us',
#                               'nst': 124,
#                               'place': '68 km WNW of Vinchina, Argentina',
#                               'rms': 1.19,
#                               'sig': 465,
#                               'sources': ',usauto,us,',
#                               'status': 'reviewed',
#                               'time': 1704269044468,
#                               'title': 'M 5.5 - 68 km WNW of Vinchina, '
#                                        'Argentina',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',internal-moment-tensor,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1710020338040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000m1cg'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [136.7689, 37.247, 6],
#                             'type': 'Point'},
#                'id': 'us6000m12f',
#                'properties': {'alert': 'green',
#                               'cdi': 2,
#                               'code': '6000m12f',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000m12f&format=geojson',
#                               'dmin': 1.347,
#                               'felt': 1,
#                               'gap': 26,
#                               'ids': ',us6000m12f,usauto6000m12f,',
#                               'mag': 5.4,
#                               'magType': 'mww',
#                               'mmi': 6.735,
#                               'net': 'us',
#                               'nst': 619,
#                               'place': '11 km W of Anamizu, Japan',
#                               'rms': 0.48,
#                               'sig': 449,
#                               'sources': ',us,usauto,',
#                               'status': 'reviewed',
#                               'time': 1704158251568,
#                               'title': 'M 5.4 - 11 km W of Anamizu, Japan',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',dyfi,internal-moment-tensor,losspager,moment-tensor,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1710020316040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000m12f'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [-118.3703333, 33.5798333, 11.44],
#                             'type': 'Point'},
#                'id': 'ci40453591',
#                'properties': {'alert': 'green',
#                               'cdi': 4.1,
#                               'code': '40453591',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40453591&format=geojson',
#                               'dmin': 0.147,
#                               'felt': 5641,
#                               'gap': 116,
#                               'ids': ',ew1704126450,ci40453591,at00s6lcdv,us6000m10b,',
#                               'mag': 4.06,
#                               'magType': 'mw',
#                               'mmi': 3.403,
#                               'net': 'ci',
#                               'nst': 138,
#                               'place': '18 km S of Rancho Palos Verdes, CA',
#                               'rms': 0.28,
#                               'sig': 664,
#                               'sources': ',ew,ci,at,us,',
#                               'status': 'reviewed',
#                               'time': 1704126452250,
#                               'title': 'M 4.1 - 18 km S of Rancho Palos '
#                                        'Verdes, CA',
#                               'tsunami': 1,
#                               'type': 'earthquake',
#                               'types': ',dyfi,focal-mechanism,impact-link,losspager,moment-tensor,nearby-cities,oaf,origin,phase-data,scitech-link,shake-alert,shakemap,',
#                               'tz': None,
#                               'updated': 1735663054307,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40453591'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [137.4029, 37.5146, 10],
#                             'type': 'Point'},
#                'id': 'us6000m0ya',
#                'properties': {'alert': 'green',
#                               'cdi': None,
#                               'code': '6000m0ya',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000m0ya&format=geojson',
#                               'dmin': 0.856,
#                               'felt': None,
#                               'gap': 50,
#                               'ids': ',us6000m0ya,',
#                               'mag': 5.6,
#                               'magType': 'mb',
#                               'mmi': 6.677,
#                               'net': 'us',
#                               'nst': 146,
#                               'place': '54 km NE of Anamizu, Japan',
#                               'rms': 0.71,
#                               'sig': 482,
#                               'sources': ',us,',
#                               'status': 'reviewed',
#                               'time': 1704100097603,
#                               'title': 'M 5.6 - 54 km NE of Anamizu, Japan',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',losspager,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1710020302040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000m0ya'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [137.4185, 37.5339, 10],
#                             'type': 'Point'},
#                'id': 'us6000m0y9',
#                'properties': {'alert': 'green',
#                               'cdi': 6.1,
#                               'code': '6000m0y9',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000m0y9&format=geojson',
#                               'dmin': 0.835,
#                               'felt': 1,
#                               'gap': 43,
#                               'ids': ',us6000m0y9,',
#                               'mag': 5.5,
#                               'magType': 'mb',
#                               'mmi': 6.348,
#                               'net': 'us',
#                               'nst': 130,
#                               'place': '56 km NE of Anamizu, Japan',
#                               'rms': 0.73,
#                               'sig': 466,
#                               'sources': ',us,',
#                               'status': 'reviewed',
#                               'time': 1704099828859,
#                               'title': 'M 5.5 - 56 km NE of Anamizu, Japan',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',dyfi,losspager,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1710020302040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000m0y9'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [136.8875, 37.2997, 10],
#                             'type': 'Point'},
#                'id': 'us6000m0xt',
#                'properties': {'alert': 'green',
#                               'cdi': None,
#                               'code': '6000m0xt',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000m0xt&format=geojson',
#                               'dmin': 1.296,
#                               'felt': None,
#                               'gap': 67,
#                               'ids': ',us6000m0xt,',
#                               'mag': 5.6,
#                               'magType': 'mww',
#                               'mmi': 6.756,
#                               'net': 'us',
#                               'nst': 148,
#                               'place': '7 km N of Anamizu, Japan',
#                               'rms': 0.52,
#                               'sig': 482,
#                               'sources': ',us,',
#                               'status': 'reviewed',
#                               'time': 1704095807661,
#                               'title': 'M 5.6 - 7 km N of Anamizu, Japan',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',losspager,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1710020298040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000m0xt'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [123.6177, -0.1092, 81.212],
#                             'type': 'Point'},
#                'id': 'us6000m0xq',
#                'properties': {'alert': 'green',
#                               'cdi': None,
#                               'code': '6000m0xq',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000m0xq&format=geojson',
#                               'dmin': 1.254,
#                               'felt': None,
#                               'gap': 42,
#                               'ids': ',us6000m0xq,',
#                               'mag': 5.3,
#                               'magType': 'mb',
#                               'mmi': 4.035,
#                               'net': 'us',
#                               'nst': 52,
#                               'place': '94 km SE of Gorontalo, Indonesia',
#                               'rms': 0.78,
#                               'sig': 432,
#                               'sources': ',us,',
#                               'status': 'reviewed',
#                               'time': 1704095563251,
#                               'title': 'M 5.3 - 94 km SE of Gorontalo, '
#                                        'Indonesia',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',losspager,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1710020298040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000m0xq'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [136.8272, 37.1895, 10],
#                             'type': 'Point'},
#                'id': 'us6000m0xm',
#                'properties': {'alert': 'green',
#                               'cdi': 8.7,
#                               'code': '6000m0xm',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000m0xm&format=geojson',
#                               'dmin': 1.278,
#                               'felt': 9,
#                               'gap': 32,
#                               'ids': ',us6000m0xm,',
#                               'mag': 6.2,
#                               'magType': 'mb',
#                               'mmi': 7.001,
#                               'net': 'us',
#                               'nst': 185,
#                               'place': '8 km SW of Anamizu, Japan',
#                               'rms': 0.4,
#                               'sig': 599,
#                               'sources': ',us,',
#                               'status': 'reviewed',
#                               'time': 1704093521584,
#                               'title': 'M 6.2 - 8 km SW of Anamizu, Japan',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',dyfi,ground-failure,losspager,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1736031181431,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000m0xm'},
#                'type': 'Feature'},
#               {'geometry': {'coordinates': [137.2491, 37.4933, 10],
#                             'type': 'Point'},
#                'id': 'us6000m0xj',
#                'properties': {'alert': 'green',
#                               'cdi': 4.3,
#                               'code': '6000m0xj',
#                               'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000m0xj&format=geojson',
#                               'dmin': 0.968,
#                               'felt': 1,
#                               'gap': 53,
#                               'ids': ',us6000m0xj,pt24001000,',
#                               'mag': 5.8,
#                               'magType': 'mb',
#                               'mmi': 6.925,
#                               'net': 'us',
#                               'nst': 279,
#                               'place': '42 km NE of Anamizu, Japan',
#                               'rms': 0.47,
#                               'sig': 518,
#                               'sources': ',us,pt,',
#                               'status': 'reviewed',
#                               'time': 1704092765477,
#                               'title': 'M 5.8 - 42 km NE of Anamizu, Japan',
#                               'tsunami': 0,
#                               'type': 'earthquake',
#                               'types': ',dyfi,impact-text,internal-origin,losspager,origin,phase-data,shakemap,',
#                               'tz': None,
#                               'updated': 1710020296040,
#                               'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000m0xj'},
#                'type': 'Feature'}],
#  'metadata': {'api': '1.14.1',
#               'count': 682,
#               'generated': 1736363437000,
#               'status': 200,
#               'title': 'USGS Earthquakes',
#               'url': 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2024-01-01&endtime=2024-12-31&alertlevel=green'},
#  'type': 'FeatureCollection'}

# %% [markdown]
# The code below produces a plot showing the longitude and latitude of the earthquakes in the data.

# %%
# imports for plotting
import matplotlib.pyplot as plt

# %%
# extract the longitudes and latitudes for the earthquake events
# the following lines of code use Python's "list comprehension" to write an accumulator loop
# if you are not familiar with list comprehension, look it up!
locations = [feature['geometry']['coordinates'] for feature in data['features']]
longitudes = [location[0] for location in locations]
latitudes = [location[1] for location in locations]

# make a matplotlib scatter plot with the longitudes and latitudes
# if you are not familiar with matplotlib, look it up!
fig, ax = plt.subplots()
ax.scatter(longitudes, latitudes, color='y', label='Events')
ax.set_xlabel(r'Longitude ($^o$)')
ax.set_ylabel(r'Latitude ($^o$)')
ax.set_title('Green Level Earthquakes in 2024')
plt.show()

# %% [markdown]
# ### Exercise 1
#
# Write a function that takes the year and the alert level ('green', 'yellow', 'orange', or 'red') as parameters and plots the earthquakes that occured that year.  Use the code above as a guide, but do not use list comprehension and do not rely on global variables in your function.

# %%
import requests
import requests
import json
import matplotlib.pyplot as plt

def plot_earthquakes(year, alert_level):
    params_dict = {'format': 'geojson', 'starttime': f'{year}-01-01', 'endtime': f'{year}-12-31', 'alertlevel': alert_level}
    api_url = 'https://earthquake.usgs.gov/fdsnws/event/1/query?'

    # make the API request
    response = requests.get(api_url, params = params_dict)

    # convert the response to json format data
    data = response.json()

    # Extract the coordinates of the earthquakes
    latitudes = []
    longitudes = []
    for feature in data['features']:
        coords = feature['geometry']['coordinates']
        longitudes.append(coords[0])
        latitudes.append(coords[1])

    # Plot the earthquakes on a scatter plot
    plt.figure(figsize=(10, 5))
    plt.scatter(longitudes, latitudes, c='green', marker='o', alpha=0.5)
    plt.title(f'Earthquakes in {year} with Alert Level: {alert_level}')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.grid(True)
    plt.show()
plot_earthquakes(2005, 'green')

# %% [markdown]
# ### Challenge Exercise
#
# Write a function that takes a start date and end date as parameters and plots all four levels of earthquakes ('green', 'yellow', 'orange' and 'red') on a single plot.

# %%
# your Challenge Ex. code here
import json
import matplotlib.pyplot as plt
import requests
